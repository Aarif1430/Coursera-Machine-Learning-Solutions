# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/aarif/Documents/WORKING/Machine Learning/SNOWDEN ML/breast_cancer.txt")

# %%
print(df)
# Out:
#           id  clump_thickness  unif_cell_size  unif_cell_shape  marg_adhesion  \
# 0    1000025                5               1                1              1
# 1    1002945                5               4                4              5
# 2    1015425                3               1                1              1
# 3    1016277                6               8                8              1
# 4    1017023                4               1                1              3
# 5    1017122                8              10               10              8
# 6    1018099                1               1                1              1
# 7    1018561                2               1                2              1
# 8    1033078                2               1                1              1
# 9    1033078                4               2                1              1
# 10   1035283                1               1                1              1
# ...

# %%
res = df['unif_cell_size'].describe()

# %%
print(res)
# Out:
# count    699.000000
# mean       3.134478
# std        3.051459
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        5.000000
# max       10.000000
# Name: unif_cell_size, dtype: float64
